# %%
# %%writefile README.md
# sdcdddccdccccdcccccccccccccccccccddddddddd
# Out:
# Overwriting README.md

# %%
# !cat README.md
# Out:
# sdcdddccdccccdcccccccccccccccccccddddddddd

# %%
# %%writefile index.html
# <!DOCTYPE html>
# <html>
# <head
# </html>
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %% [markdown]
# # saving to online

# %%
# %%bash
# git add --all :/
# git commit -a -m 'added readme'
# git push origin master
# Out:
# [master a9c52e6] added readme
#  3 files changed, 157 insertions(+)
#  create mode 100644 .ipynb_checkpoints/My Notebook-checkpoint.ipynb
#  create mode 100644 My Notebook.ipynb
# To git@github.com:ciire/ciire.github.io.git
#    ed267b9..a9c52e6  master -> master
